// %% [markdown]
// # Chessboard
//
// Scrivi un programma che genera una stringa che rappresenta una schacchiera 8x8.
// Usa i caratteri di "a capo" per separare le linee, uno spazio per rappresentare le caselle bianche e un cancelletto per rappresentare quelle nere.
//
// ## Esempio
//
// ```txt
//  # # # #
// # # # #
//  # # # #
// # # # #
//  # # # #
// # # # #
//  # # # #
// # # # #
// ```
//
// Dopo aver scritto un programma che genera la scacchiera 8x8, moficalo per avere una variabile `size = 8` e modifica il programma in modo tale da funzionare per ogni dimensione della scacchiera.

// %%
#include <string>
#include <iostream>
using namespace std;

const int size = 8;
